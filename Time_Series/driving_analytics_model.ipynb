# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow.keras.models import Model, Sequential, save_model
from tensorflow.keras.layers import GRU, Dense, Dropout, Input, Bidirectional, Conv1D, BatchNormalization, Flatten
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
from sklearn.mixture import GaussianMixture
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Function to load data from the database
def load_data_from_db(engine, table_name, columns=None):
    query = f"SELECT {', '.join(columns)} FROM {table_name};"
    df = pd.read_sql(query, engine)
    return df

# Function to create sequences for multi-target
def create_sequences(data, target, sequence_length):
    sequences = []
    targets = []
    for i in range(len(data) - sequence_length):
        sequences.append(data[i:i + sequence_length])
        targets.append(target[i + sequence_length])
    return np.array(sequences), np.array(targets)

# Database connection parameters
db_params = {
    'host': '194.171.191.226',
    'port': '6379',
    'database': 'postgres',
    'user': 'group20',
    'password': 'blockd_2024group20_28'
}

db_url = f"postgresql://{db_params['user']}:{db_params['password']}@{db_params['host']}:{db_params['port']}/{db_params['database']}"
engine = create_engine(db_url)

# Load the data with only necessary columns
table_name = "data_lake.safe_driving"
columns = ['is_valid', 'category', 'incident_severity', 'event_start', 'latitude', 'longitude', 'speed_kmh', 'end_speed_kmh', 'maxwaarde']
df = load_data_from_db(engine, table_name, columns)

# Filter data where is_valid is TRUE
df = df[df['is_valid'] == True]

# Clean the 'category' field to remove trailing spaces
df['category'] = df['category'].str.strip()

# Filter for speeding incidents
speeding_df = df[df['category'] == 'SPEED'].copy()

# Extract the severity number from 'incident_severity'
speeding_df['severity'] = speeding_df['incident_severity'].str.extract(r'(\d+)').astype(int)

# Print the count of speeding incidents
print("Number of speeding incidents:", len(speeding_df))

# Ensure there are enough samples for splitting
if len(speeding_df) < 2:
    raise ValueError("Not enough samples to split into training and testing sets.")

# Feature Engineering
speeding_df['event_start'] = pd.to_datetime(speeding_df['event_start'])
speeding_df['hour'] = speeding_df['event_start'].dt.hour
speeding_df['day_of_week'] = speeding_df['event_start'].dt.dayofweek
speeding_df['month'] = speeding_df['event_start'].dt.month

# Zone labels using GaussianMixture
num_zones = 5 
gmm = GaussianMixture(n_components=num_zones, random_state=42)
speeding_df['zone'] = gmm.fit_predict(speeding_df[['latitude', 'longitude']])

# Select features and targets for zone
features_zone = ['latitude', 'longitude', 'speed_kmh', 'end_speed_kmh', 'maxwaarde', 'hour', 'day_of_week', 'month']
target_zone = 'zone'

X_zone = speeding_df[features_zone]
y_zone = speeding_df[target_zone]

# Normalize features using StandardScaler
scaler_zone = StandardScaler()
X_scaled_zone = scaler_zone.fit_transform(X_zone)

# Convert zone labels to one-hot encoding
y_zone_encoded = to_categorical(y_zone, num_classes=num_zones)

# Set sequence length
seq_len_zone = 10

# Create sequences for zone prediction
X_sequences_zone, y_sequences_zone = create_sequences(X_scaled_zone, y_zone_encoded, seq_len_zone)

# Split into train, validation, and test sets (70%, 10%, 20%)
X_train_full_zone, X_test_zone, y_train_full_zone, y_test_zone = train_test_split(
    X_sequences_zone, y_sequences_zone, test_size=0.2, random_state=42
)
X_train_zone, X_val_zone, y_train_zone, y_val_zone = train_test_split(
    X_train_full_zone, y_train_full_zone, test_size=0.125, random_state=42
)  # 0.125 * 0.8 = 0.1

# Print shapes to verify
print(f"Sequence length: {seq_len_zone}")
print(f"Training sequences shape: {X_train_zone.shape}")
print(f"Validation sequences shape: {X_val_zone.shape}")
print(f"Test sequences shape: {X_test_zone.shape}")

# Define the model using functional API
input_layer_zone = Input(shape=(seq_len_zone, X_train_zone.shape[2]))

# GRU layers
x_zone = Bidirectional(GRU(64, return_sequences=True, activation='relu', kernel_regularizer=l2(0.01)))(input_layer_zone)
x_zone = Dropout(0.3)(x_zone)
x_zone = Bidirectional(GRU(64, activation='relu', kernel_regularizer=l2(0.01)))(x_zone)
x_zone = Dropout(0.3)(x_zone)

# Output layer for zone
zone_output = Dense(num_zones, activation='softmax', name='zone_output')(x_zone)

model_zone = Model(inputs=input_layer_zone, outputs=zone_output)

# Compile the model
model_zone.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model
model_zone.summary()

# Callbacks for early stopping, learning rate reduction, and model checkpoint
early_stopping_zone = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr_zone = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001)
model_checkpoint_zone = ModelCheckpoint('zone_prediction_model_checkpoint.keras', monitor='val_loss', save_best_only=True, mode='min')

# Train the model with adjusted batch size
history_zone = model_zone.fit(
    X_train_zone, y_train_zone,
    epochs=15, batch_size=128, validation_data=(X_val_zone, y_val_zone),
    callbacks=[early_stopping_zone, reduce_lr_zone, model_checkpoint_zone]
)

# Plot training & validation loss values for zone
plt.figure(figsize=(10, 6))
plt.plot(history_zone.history['loss'], label='Train loss (zone)')
plt.plot(history_zone.history['val_loss'], label='Validation loss (zone)')
plt.title('GRU Model loss for Zone')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# Plot training & validation accuracy values for zone
plt.figure(figsize=(10, 6))
plt.plot(history_zone.history['accuracy'], label='Train accuracy (zone)')
plt.plot(history_zone.history['val_accuracy'], label='Validation accuracy (zone)')
plt.title('GRU Model accuracy for Zone')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# Now the severity prediction model
features_severity = ['latitude', 'longitude', 'speed_kmh', 'end_speed_kmh', 'maxwaarde', 'hour', 'day_of_week', 'month']
target_severity = 'severity'

X_severity = speeding_df[features_severity]
y_severity = speeding_df[target_severity]

# Normalize features using MinMaxScaler
scaler_severity = MinMaxScaler()
X_scaled_severity = scaler_severity.fit_transform(X_severity)

# Set sequence lengths to test for severity prediction
sequence_lengths = [5, 10]

for seq_len in sequence_lengths:
    # Create sequences for severity prediction
    X_sequences_severity, y_sequences_severity = create_sequences(X_scaled_severity, y_severity.values, seq_len)
    
    # Split into train, validation, and test sets (70%, 10%, 20%)
    X_train_full_severity, X_test_severity, y_train_full_severity, y_test_severity = train_test_split(
        X_sequences_severity, y_sequences_severity, test_size=0.2, random_state=42
    )
    X_train_severity, X_val_severity, y_train_severity, y_val_severity = train_test_split(
        X_train_full_severity, y_train_full_severity, test_size=0.125, random_state=42
    )  # 0.125 * 0.8 = 0.1
    
    # Define the TCN model for severity prediction
    model_severity = Sequential()
    model_severity.add(Conv1D(filters=32, kernel_size=2, padding='causal', activation='relu', input_shape=(X_train_severity.shape[1], X_train_severity.shape[2])))
    model_severity.add(BatchNormalization())
    model_severity.add(Dropout(0.3))
    model_severity.add(Conv1D(filters=64, kernel_size=2, padding='causal', activation='relu'))
    model_severity.add(BatchNormalization())
    model_severity.add(Dropout(0.3))
    model_severity.add(Conv1D(filters=128, kernel_size=2, padding='causal', activation='relu'))
    model_severity.add(BatchNormalization())
    model_severity.add(Dropout(0.3))
    model_severity.add(Flatten())
    model_severity.add(Dense(1))
    
    # Compile the model
    model_severity.compile(optimizer='adam', loss='mse', metrics=['mae'])
    print(f"Summary of the TCN model for sequence length {seq_len}:")
    model_severity.summary()
    
    # Callbacks for early stopping, learning rate reduction, and model checkpoint
    early_stopping_severity = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    reduce_lr_severity = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
    model_checkpoint_severity = ModelCheckpoint(
        f'severity_prediction_model_checkpoint_{seq_len}.keras',
        monitor='val_loss',
        save_best_only=True,
        mode='min'
    )
    
    # Train the TCN model
    history_severity = model_severity.fit(
        X_train_severity, y_train_severity,
        epochs=10, batch_size=128,
        validation_data=(X_val_severity, y_val_severity),
        callbacks=[early_stopping_severity, reduce_lr_severity, model_checkpoint_severity]
    )
    
    # Save the trained model
    save_model(model_severity, f'severity_prediction_model_{seq_len}.h5')
    
    # Plot training & validation loss values for severity
    plt.figure(figsize=(10, 6))
    plt.plot(history_severity.history['loss'], label='Train loss')
    plt.plot(history_severity.history['val_loss'], label='Validation loss')
    plt.title(f'Model loss for sequence length {seq_len}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()
    
    # Evaluate the model
    loss_severity, mae_severity = model_severity.evaluate(X_test_severity, y_test_severity)
    print(f"Sequence length: {seq_len}, Test loss: {loss_severity}, Test MAE: {mae_severity}")
# Out:
# Number of speeding incidents: 386791
# Sequence length: 10
# Training sequences shape: (270746, 10, 8)
# Validation sequences shape: (38678, 10, 8)
# Test sequences shape: (77357, 10, 8)
# Model: "functional_25"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 10, 8)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ (None, 10, 128)        │        28,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 10, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_3 (Bidirectional) │ (None, 128)            │        74,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ zone_output (Dense)             │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 103,557 (404.52 KB)
#  Trainable params: 103,557 (404.52 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/15
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 27s 8ms/step - accuracy: 0.2860 - loss: 1.7576 - val_accuracy: 0.2955 - val_loss: 1.4267 - learning_rate: 0.0010
# Epoch 2/15
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.2934 - loss: 1.4255 - val_accuracy: 0.2955 - val_loss: 1.4259 - learning_rate: 0.0010
# Epoch 3/15
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.2950 - loss: 1.4251 - val_accuracy: 0.2955 - val_loss: 1.4258 - learning_rate: 0.0010
# Epoch 4/15
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.2966 - loss: 1.4245 - val_accuracy: 0.2955 - val_loss: 1.4257 - learning_rate: 0.0010
# Epoch 5/15
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.2967 - loss: 1.4239 - val_accuracy: 0.2955 - val_loss: 1.4258 - learning_rate: 0.0010
# Epoch 6/15
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.2962 - loss: 1.4252 - val_accuracy: 0.2955 - val_loss: 1.4258 - learning_rate: 0.0010
# Epoch 7/15
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.2969 - loss: 1.4238 - val_accuracy: 0.2955 - val_loss: 1.4257 - learning_rate: 0.0010
# Epoch 8/15
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.2960 - loss: 1.4264 - val_accuracy: 0.2955 - val_loss: 1.4259 - learning_rate: 0.0010
# Epoch 9/15
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.2956 - loss: 1.4262 - val_accuracy: 0.2955 - val_loss: 1.4256 - learning_rate: 0.0010
# Epoch 10/15
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.2945 - loss: 1.4257 - val_accuracy: 0.2955 - val_loss: 1.4258 - learning_rate: 0.0010
# Epoch 11/15
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.2965 - loss: 1.4239 - val_accuracy: 0.2955 - val_loss: 1.4258 - learning_rate: 0.0010
# Epoch 12/15
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.2962 - loss: 1.4245 - val_accuracy: 0.2955 - val_loss: 1.4258 - learning_rate: 0.0010
# Epoch 13/15
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.2955 - loss: 1.4245 - val_accuracy: 0.2955 - val_loss: 1.4260 - learning_rate: 0.0010
# Epoch 14/15
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.2957 - loss: 1.4241 - val_accuracy: 0.2955 - val_loss: 1.4257 - learning_rate: 0.0010
# Epoch 15/15
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.2961 - loss: 1.4247 - val_accuracy: 0.2955 - val_loss: 1.4257 - learning_rate: 0.0010
# Summary of the TCN model for sequence length 5:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_6 (Conv1D)               │ (None, 5, 32)          │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 5, 32)          │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 5, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 5, 64)          │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 5, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 5, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_8 (Conv1D)               │ (None, 5, 128)         │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 5, 128)         │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 5, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 640)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           641 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,753 (88.88 KB)
#  Trainable params: 22,305 (87.13 KB)
#  Non-trainable params: 448 (1.75 KB)
# Epoch 1/10
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 17s 4ms/step - loss: 0.4035 - mae: 0.3829 - val_loss: 0.1000 - val_mae: 0.2122 - learning_rate: 0.0010
# Epoch 2/10
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.1032 - mae: 0.1739 - val_loss: 0.1020 - val_mae: 0.2261 - learning_rate: 0.0010
# Epoch 3/10
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.1002 - mae: 0.1662 - val_loss: 0.1093 - val_mae: 0.2578 - learning_rate: 0.0010
# Epoch 4/10
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0971 - mae: 0.1601 - val_loss: 0.0977 - val_mae: 0.2017 - learning_rate: 0.0010
# Epoch 5/10
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0971 - mae: 0.1581 - val_loss: 0.0958 - val_mae: 0.1879 - learning_rate: 0.0010
# Epoch 6/10
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0965 - mae: 0.1580 - val_loss: 0.0950 - val_mae: 0.1722 - learning_rate: 0.0010
# Epoch 7/10
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0971 - mae: 0.1574 - val_loss: 0.0952 - val_mae: 0.1821 - learning_rate: 0.0010
# Epoch 8/10
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0966 - mae: 0.1579 - val_loss: 0.0944 - val_mae: 0.1458 - learning_rate: 0.0010
# Epoch 9/10
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0956 - mae: 0.1565 - val_loss: 0.0942 - val_mae: 0.1574 - learning_rate: 0.0010
# Epoch 10/10
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0961 - mae: 0.1576 - val_loss: 0.0943 - val_mae: 0.1548 - learning_rate: 0.0010
# WARNING: You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2418/2418 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0907 - mae: 0.1559
# Sequence length: 5, Test loss: 0.09266136586666107, Test MAE: 0.15666328370571136
# Summary of the TCN model for sequence length 10:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_9 (Conv1D)               │ (None, 10, 32)         │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 10, 32)         │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 10, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_10 (Conv1D)              │ (None, 10, 64)         │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 10, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 10, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_11 (Conv1D)              │ (None, 10, 128)        │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 10, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 10, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │         1,281 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,393 (91.38 KB)
#  Trainable params: 22,945 (89.63 KB)
#  Non-trainable params: 448 (1.75 KB)
# Epoch 1/10
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - loss: 0.4022 - mae: 0.3833 - val_loss: 0.0980 - val_mae: 0.1982 - learning_rate: 0.0010
# Epoch 2/10
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.1062 - mae: 0.1811 - val_loss: 0.0950 - val_mae: 0.1926 - learning_rate: 0.0010
# Epoch 3/10
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1003 - mae: 0.1650 - val_loss: 0.0927 - val_mae: 0.1622 - learning_rate: 0.0010
# Epoch 4/10
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0993 - mae: 0.1619 - val_loss: 0.0931 - val_mae: 0.1374 - learning_rate: 0.0010
# Epoch 5/10
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0977 - mae: 0.1593 - val_loss: 0.0929 - val_mae: 0.1645 - learning_rate: 0.0010
# Epoch 6/10
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0967 - mae: 0.1580 - val_loss: 0.0944 - val_mae: 0.1196 - learning_rate: 0.0010
# Epoch 7/10
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0966 - mae: 0.1568 - val_loss: 0.0944 - val_mae: 0.1193 - learning_rate: 0.0010
# Epoch 8/10
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0961 - mae: 0.1567 - val_loss: 0.0938 - val_mae: 0.1860 - learning_rate: 0.0010
# Epoch 9/10
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0961 - mae: 0.1570 - val_loss: 0.0934 - val_mae: 0.1804 - learning_rate: 5.0000e-04
# Epoch 10/10
# 2116/2116 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0945 - mae: 0.1550 - val_loss: 0.0925 - val_mae: 0.1512 - learning_rate: 5.0000e-04
# WARNING: You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2418/2418 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0933 - mae: 0.1510
# Sequence length: 10, Test loss: 0.09324309229850769, Test MAE: 0.15154048800468445
